# %%
import json
from pathlib import Path

# Path to the existing software profile
profile_path = Path("llm-vulvariant/repo-profiles/llama_index")

# Load profile (supports JSON profile files)
profile_file = next(profile_path.glob("*.json"))
with profile_file.open("r", encoding="utf-8") as f:
    software_profile = json.load(f)

software_profile
